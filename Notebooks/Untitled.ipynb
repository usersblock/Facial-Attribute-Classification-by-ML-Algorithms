# %%
d = {'jen':2, 'Dari': 3, 'vane': 5}

# %%
d.get('jen')
# Out:
# 2

# %%
# importing pymongo
from pymongo import MongoClient
#connect_uri = "mongodb+srv://jvivar:<Soyunaloca1>@cluster0.wqpgh.mongodb.net/?retryWrites=true&w=majority"
connect_uri = 'mongodb+srv://cmk:342124@todolist-c483l.gcp.mongodb.net/search?retryWrites=true&w=majority'
# establing connection
try:
    connect = MongoClient(connect_uri)
    print("Connected successfully!!!")
except:
    print("Could not connect to MongoDB")

# connecting or switching to the database
db = connect.demoDB

# creating or switching to demoCollection
collection = db.demoCollection

# first document
document1 = {
        "name":"John",
        "age":24,
        "location":"New York"
        }
#second document
document2 = {
        "name":"Sam",
        "age":21,
        "location":"Chicago"
        }

# Inserting both document one by one
collection.insert_one(document1)
collection.insert_one(document2)



# Printing the data inserted
cursor = collection.find()
for record in cursor:
    print(record)
# Out:
# Connected successfully!!!
# {'_id': ObjectId('628aff95d77f51d5980596ca'), 'name': 'John', 'age': 24, 'location': 'New York'}
# {'_id': ObjectId('628aff96d77f51d5980596cb'), 'name': 'Sam', 'age': 21, 'location': 'Chicago'}

# %%
cursor = collection.find()
for record in cursor:
    print(record)

# %%
#
# Web crawler module
#

# import libraries
import json
import requests
from bs4 import BeautifulSoup
import pymongo


from sklearn.feature_extraction.text import TfidfVectorizer
import pymongo
from flask import Flask, request, render_template, flash
from flask_paginate import Pagination, get_page_args
import mysql.connector
from mysql.connector import Error
import re
import string 
import numpy as np
import pandas as pd

connection = mysql.connector.connect(host='localhost',database='MY_CUSTOM_BOT',
                                      user='root',password='Soyunaloca1',
                                      auth_plugin='caching_sha2_password')
 
cursor = connection.cursor()

 #description column is tbd based on the new name of the database

sql = "select * from urls_table"

cursor.execute(sql)
results = cursor.fetchall()

browser = []
keyword = []
url = []
search_results = []
for tup in results:
    i,brow, key, url_ = tup
    browser.append(brow)
    keyword.append(key)
    url.append(url_)
for i in range(len(browser)):
    
    result = {
        'search_engine': browser[i],
        'key_word': keyword[i],
        'URL': url[i]}

    connect_uri = 'mongodb+srv://cmk:342124@todolist-c483l.gcp.mongodb.net/search?retryWrites=true&w=majority'
    #connect_uri = "mongodb+srv://jvivar:<Soyunaloca1>@cluster0.wqpgh.mongodb.net/?retryWrites=true&w=majority"
    client = pymongo.MongoClient(connect_uri)
   # db = client.database
    db = client.demoDB
    #collection = db.my_gfg_collection
    collection = db.demoCollection
    collection.insert_one(result)
    

#

# %%
cursor = collection.find()
for record in cursor:
    print(record)
# Out:
# {'_id': ObjectId('628aff95d77f51d5980596ca'), 'name': 'John', 'age': 24, 'location': 'New York'}
# {'_id': ObjectId('628aff96d77f51d5980596cb'), 'name': 'Sam', 'age': 21, 'location': 'Chicago'}
# {'_id': ObjectId('628b00600d3aacd5cb2922ab'), 'search_engine': 'Google', 'key_word': 'house plants', 'URL': 'https://www.countryliving.com/gardening/g26753835/indoor-trees/'}
# {'_id': ObjectId('628b00610d3aacd5cb2922ad'), 'search_engine': 'Google', 'key_word': 'house plants', 'URL': 'https://www.countryliving.com/gardening/garden-ideas/g26829528/bedroom-plants/'}
# {'_id': ObjectId('628b00620d3aacd5cb2922af'), 'search_engine': 'Google', 'key_word': 'house plants', 'URL': 'https://www.target.com/p/large-verigated-plant-threshold-8482/-/A-83228277?ref=tgt_adv_XS000000&AFID=google_pla_df_free_local&CPNG=Home%2BDecor&adgroup=65-7'}
# ...
